# %%
import requests
import pandas as pd
import json

# %%
peyton = requests.get('https://sports.core.api.espn.com/v2/sports/football/leagues/nfl/athletes/1428/statistics/0')
peyton.status_code
# Out:
# 200

# %%
peytonm = peyton.json()
peytonm
# Out:
# {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/athletes/1428/statistics/0?lang=en&region=us',
#  'athlete': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/athletes/1428?lang=en&region=us'},
#  'splits': {'id': '0',
#   'name': 'All Splits',
#   'abbreviation': 'Any',
#   'categories': [{'name': 'general',
#     'displayName': 'General',
#     'shortDisplayName': 'General',
#     'abbreviation': 'gen',
#     'summary': '',
#     'stats': [{'name': 'fumbles',
#       'displayName': 'Fumbles',
#       'shortDisplayName': 'F',
#       'description': 'The number of times a player/team has fumbled the ball',
#       'abbreviation': 'FUM',
#       'value': 75.0,
#       'displayValue': '75'},
#      {'name': 'fumblesLost',
#       'displayName': 'Fumbles Lost',
#       'shortDisplayName': 'FL',
#       'description': 'The number of times a fumble is recovered by the opposing team',
#       'abbreviation': 'LST',
#       'value': 28.0,
# ...

# %%
eli = requests.get('https://sports.core.api.espn.com/v2/sports/football/leagues/nfl/athletes/5526/statistics/0')
eli.status_code
# Out:
# 200

# %%
elim = eli.json()
elim
# Out:
# {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/athletes/5526/statistics/0?lang=en&region=us',
#  'athlete': {'$ref': 'http://sports.core.api.espn.com/v2/sports/football/leagues/nfl/athletes/5526?lang=en&region=us'},
#  'splits': {'id': '0',
#   'name': 'All Splits',
#   'abbreviation': 'Any',
#   'categories': [{'name': 'general',
#     'displayName': 'General',
#     'shortDisplayName': 'General',
#     'abbreviation': 'gen',
#     'summary': '',
#     'stats': [{'name': 'fumbles',
#       'displayName': 'Fumbles',
#       'shortDisplayName': 'F',
#       'description': 'The number of times a player/team has fumbled the ball',
#       'abbreviation': 'FUM',
#       'value': 125.0,
#       'displayValue': '125'},
#      {'name': 'fumblesLost',
#       'displayName': 'Fumbles Lost',
#       'shortDisplayName': 'FL',
#       'description': 'The number of times a fumble is recovered by the opposing team',
#       'abbreviation': 'LST',
#       'value': 55.0,
# ...
